# %% [markdown]
# # Calculate Q-Rookley
#
# - Input data "20172022_processed_1_3_4.csv", from 2017/7/1 to 2022/12/17
#
# - Use logreturn instead of logreturn+1
#
# - Use
# ```
# r.source('Q_Rookley_main.R')
# ```
# and
# ```
# 'EPK_library.r'
# ```
# to calculate Q_Rookley, along with
# ```
# BTC_USD_Quandl_2011_2023.csv
# ```
# for BTC daily price data.
#
# - Interest rate: 0
#
# - Moneyness range is [0.5, 2]
#
# - Bandwidth 0.3
#
# - tau = 3 : 60
#
# - Delete options given a certain date, tau and strike, i.e. option(t, tau, strike), with observations less than 200

# %%
import pandas as pd
import Q_Rookley.Rookley_Q_20170701to20221217_IR0
# Out:
# Using Macos Locale
# 2023-08-23
# 2023-08-23 00:00:00
# /Users/irtg/同步空间/Pricing_Kernel/EPK/prepared_code/Q_Rookley/Rookley_Q_1723_20170701to20230830_IR0.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['interest_rate'] = 0
# /Users/irtg/同步空间/Pricing_Kernel/EPK/prepared_code/Q_Rookley/Rookley_Q_1723_20170701to20230830_IR0.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['days_to_maturity'] = df3['tau']
# ...
